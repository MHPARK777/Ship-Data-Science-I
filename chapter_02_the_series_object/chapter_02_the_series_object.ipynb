# %%
import pandas as pd
import numpy as np

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
ice_cream_flavors = [
    'chocolate',
    'vanilla',
    'strawberry',
    'rum raisin',
]

pd.Series(ice_cream_flavors)
# Out:
# 0     chocolate
# 1       vanilla
# 2    strawberry
# 3    rum raisin
# dtype: object

# %%
pd.Series(ice_cream_flavors)
pd.Series(data=ice_cream_flavors)
# Out:
# 0     chocolate
# 1       vanilla
# 2    strawberry
# 3    rum raisin
# dtype: object

# %%
ice_cream_flavors = [
    'chocolate',
    'vanilla',
    'strawberry',
    'rum raisin',
]

days_of_week = ('Monday', 'Wednesday', 'Friday', 'Saturday')
days_of_week = ['Monday', 'Wednesday', 'Friday', 'Saturday']

pd.Series(ice_cream_flavors, days_of_week)
pd.Series(data=ice_cream_flavors, index=days_of_week)
# Out:
# Monday        chocolate
# Wednesday       vanilla
# Friday       strawberry
# Saturday     rum raisin
# dtype: object

# %%
lucky_numbers = [4, 8, 15, 16, 23, 42]
pd.Series(lucky_numbers, dtype='float')
# Out:
# 0     4.0
# 1     8.0
# 2    15.0
# 3    16.0
# 4    23.0
# 5    42.0
# dtype: float64

# %%
temperatures = [94, 88, np.nan, 91]
pd.Series(data=temperatures)
# Out:
# 0    94.0
# 1    88.0
# 2     NaN
# 3    91.0
# dtype: float64

# %%
calorie_info = {
    'Cereal': 125,
    'Chocolate Bar': 406,
    'Ice Cream Sundae': 342,
}

diet=pd.Series(calorie_info)
diet
# Out:
# Cereal              125
# Chocolate Bar       406
# Ice Cream Sundae    342
# dtype: int64

# %%
rgb_colors = [(120, 41, 26), (196, 165, 45)]
pd.Series(rgb_colors)
# Out:
# 0     (120, 41, 26)
# 1    (196, 165, 45)
# dtype: object

# %%
my_set = {'Ricky', 'Bobby'}
pd.Series(my_set)

# set은 파이썬에서 "순서가 없는(unordered)" 자료형입니다.

# pandas.Series는 순서(index)에 따라 원소를 저장해야 하기 때문에, 입력으로 들어오는 데이터는 **순서가 정의된 시퀀스(list, tuple, numpy array 등)**여야 합니다.

# 따라서 set을 그대로 넘기면 pandas가 내부적으로 순서를 부여할 수 없어서 TypeError가 발생합니다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4239893775.py in <cell line: 0>()
#       1 my_set = {'Ricky', 'Bobby'}
# ----> 2 pd.Series(my_set)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     582                 data = data.copy()
#     583         else:
# --> 584             data = sanitize_array(data, index, dtype, copy)
#     585
#     586             manager = _get_option("mode.data_manager", silent=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     640
#     641     else:
# --> 642         _sanitize_non_ordered(data)
#     643         # materialize e.g. generators, convert e.g. tuples, abc.ValueView
#     644         data = list(data)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/construction.py in _sanitize_non_ordered(data)
#     691     """
#     692     if isinstance(data, (set, frozenset)):
# --> 693         raise TypeError(f"'{type(data).__name__}' type is unordered")
#     694
#     695
#
# TypeError: 'set' type is unordered

# %%
pd.Series(list(my_set))
# Out:
# 0    Ricky
# 1    Bobby
# dtype: object

# %%
random_data = np.random.randint(1, 101, 10)
random_data
# Out:
# array([ 12,   9,  82, 100,   2,  99,  84,  13,   9,  11])

# %%
pd.Series(random_data)
# Out:
# 0     12
# 1      9
# 2     82
# 3    100
# 4      2
# 5     99
# 6     84
# 7     13
# 8      9
# 9     11
# dtype: int64

# %%
diet.values
# Out:
# array([125, 406, 342])

# %%
type(diet.values)
# Out:
# numpy.ndarray

# %%
diet.index
# Out:
# Index(['Cereal', 'Chocolate Bar', 'Ice Cream Sundae'], dtype='object')

# %%
type(diet.index)
# Out:
# pandas.core.indexes.base.Index

# %%
diet.dtype
# Out:
# dtype('int64')

# %%
diet.size
# Out:
# 3

# %%
diet.shape
# Out:
# (3,)

# %%
diet.is_unique
# Out:
# True

# %%
pd.Series(data=[3,3]).is_unique
# Out:
# False

# %%
pd.Series(data=[1,3,6]).is_monotonic_increasing
# Out:
# True

# %%
pd.Series(data=[1,6,3]).is_monotonic_increasing
# Out:
# False

# %%
values=range(0,500,5)
nums=pd.Series(data=values)
nums
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
nums.head(3)
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.head(n=3)
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
nums.head()
# Out:
# 0     0
# 1     5
# 2    10
# 3    15
# 4    20
# dtype: int64

# %%
nums.tail(6)
# Out:
# 94    470
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
nums.tail()
# Out:
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
numbers=pd.Series([1,2,3,np.nan,4,5])
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.count()
# Out:
# np.int64(5)

# %%
numbers.sum()
# Out:
# np.float64(15.0)

# %%
numbers.sum(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.sum(min_count=3)
# Out:
# np.float64(15.0)

# %%
numbers.sum(min_count=count=6)
# Out:
#   File "/tmp/ipython-input-657876979.py", line 1
#     numbers.sum(min_count=count=6)
#                                ^
# SyntaxError: invalid syntax

# %%
numbers.product()
# Out:
# np.float64(120.0)

# %%
numbers.product(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.product(min_count=3)
# Out:
# np.float64(120.0)

# %%
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna=False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.pct_change()
# Out:
# /tmp/ipython-input-527026991.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numberss = pd.Series([-1,-2,-3])
numberss.pct_change()
# Out:
# 0    NaN
# 1    1.0
# 2    0.5
# dtype: float64

# %%
numbers.pct_change()
numbers.pct_change(fill_method='pad')
numbers.pct_change(fill_method='ffill')
# Out:
# /tmp/ipython-input-2590511652.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# /tmp/ipython-input-2590511652.py:2: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='pad')
# /tmp/ipython-input-2590511652.py:3: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='ffill')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
numbers.pct_change(fill_method='bfill')
numbers.pct_change(fill_method='backfill')
# Out:
# /tmp/ipython-input-2287669325.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='bfill')
# /tmp/ipython-input-2287669325.py:2: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method='backfill')
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
numbers.mean()
# Out:
# np.float64(3.0)

# %%
numbers.median()
# Out:
# 3.0

# %%
numbers.std()
# Out:
# 1.5811388300841898

# %%
numbers.max()
# Out:
# 5.0

# %%
numbers.min()
# Out:
# 1.0

# %%
animals = pd.Series(['koala', 'aardvark', 'zebra'])
animals
# Out:
# 0       koala
# 1    aardvark
# 2       zebra
# dtype: object

# %%
animals.max()
# Out:
# 'zebra'

# %%
animals.min()
# Out:
# 'aardvark'

# %%
numbers.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
numbers.sample(3)
# Out:
# 2    3.0
# 4    4.0
# 1    2.0
# dtype: float64

# %%
authors = pd.Series(['Hemingway', 'Orwell', 'Dostoevsky', 'Fitzgerald', 'Orwell'])
authors.unique()
# Out:
# array(['Hemingway', 'Orwell', 'Dostoevsky', 'Fitzgerald'], dtype=object)

# %%
authors.nunique()
# Out:
# 4

# %%
s1=pd.Series(data=[5,np.nan,15], index=['a','b','c'])
s1
# Out:
# a     5.0
# b     NaN
# c    15.0
# dtype: float64

# %%
s1+3
# Out:
# a     8.0
# b     NaN
# c    18.0
# dtype: float64

# %%
s1.add(3)
# Out:
# a     8.0
# b     NaN
# c    18.0
# dtype: float64

# %%
s1-5
s1.sub(5)
s1.subtract(5)
# Out:
# a     0.0
# b     NaN
# c    10.0
# dtype: float64

# %%
s1*2
s1.mul(2)
s1.multiply(2)
# Out:
# a    10.0
# b     NaN
# c    30.0
# dtype: float64

# %%
s1/2
s1.div(2)
s1.divide(2)
# Out:
# a    2.5
# b    NaN
# c    7.5
# dtype: float64

# %%
s1//4
s1.floordiv(4)
# Out:
# a    1.0
# b    NaN
# c    3.0
# dtype: float64

# %%
s1%3
s1.mod(3)
# Out:
# a    2.0
# b    NaN
# c    0.0
# dtype: float64

# %%
s1=pd.Series([1,2,3], index=['a','b','c'])
s2=pd.Series([4,5,6], index=['a','b','c'])

# %%
s1+s2
# Out:
# a    5
# b    7
# c    9
# dtype: int64

# %%
s1=pd.Series([3,6,np.nan,12])
s2=pd.Series([2,6,np.nan,12])

# %%
s1==s2
s1.eq(s2)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s1 != s2
s1.ne(s2)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s1=pd.Series(data=[5,10,15], index=['a','b','c'])
s2=pd.Series(data=[4,8,12,14], index=['b','c','d','e'])

# %%
s1+s2
# Out:
# a     NaN
# b    14.0
# c    23.0
# d     NaN
# e     NaN
# dtype: float64

# %%
cities=pd.Series(data=['san francisco','los angeles','las vegas',np.nan])

# %%
len(cities)
# Out:
# 4

# %%
type(cities)
# Out:
# pandas.core.series.Series

# %%
dir(cities)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pandas_priority__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_align_for_op',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_binop',
#  '_can_hold_na',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_expanddim_from_mgr',
#  '_constructor_from_mgr',
#  '_data',
#  '_deprecate_downcast',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_duplicated',
#  '_find_valid_index',
#  '_flags',
#  '_flex_method',
#  '_from_mgr',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_index_resolvers',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_rows_with_mask',
#  '_get_value',
#  '_get_values_tuple',
#  '_get_with',
#  '_getitem_slice',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_dict',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_copy',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_is_view_after_cow_rules',
#  '_item_cache',
#  '_ixs',
#  '_logical_func',
#  '_logical_method',
#  '_map_values',
#  '_maybe_update_cacher',
#  '_memory_usage',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_name',
#  '_needs_reindex_multi',
#  '_pad_or_backfill',
#  '_protect_consolidate',
#  '_reduce',
#  '_references',
#  '_reindex_axes',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_single',
#  '_repr_data_resource_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_labels',
#  '_set_name',
#  '_set_value',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_shift_with_freq',
#  '_slice',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_latex_via_styler',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'autocorr',
#  'axes',
#  'backfill',
#  'between',
#  'between_time',
#  'bfill',
#  'bool',
#  'case_when',
#  'clip',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'divmod',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'ewm',
#  'expanding',
#  'explode',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'interpolate',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'items',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'list',
#  'loc',
#  'lt',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'rdivmod',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'searchsorted',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'std',
#  'str',
#  'struct',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_latex',
#  'to_list',
#  'to_markdown',
#  'to_numpy',
#  'to_period',
#  'to_pickle',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %%
list(cities)
# Out:
# ['san francisco', 'los angeles', 'las vegas', nan]

# %%
cities
# Out:
# 0    san francisco
# 1      los angeles
# 2        las vegas
# 3              NaN
# dtype: object

# %%
dict(cities)
# Out:
# {0: 'san francisco', 1: 'los angeles', 2: 'las vegas', 3: nan}

# %%
'las vegas' in cities
# Out:
# False

# %%
2 in cities
# Out:
# True

# %%
'las vegas' in cities.values
# Out:
# True

# %%
100 not in cities
# Out:
# True

# %%
'paris' not in cities.values
# Out:
# True

# %%
superheroes = [
    'batman',
    'superman',
    'spiderman',
    'iron man',
    'captain america',
    'wonder woman'
]

strength_levels=(100, 120, 90, 95, 110, 120)

# %%
s1 = pd.Series(superheroes)

# %%
s2 = pd.Series(strength_levels)

# %%
heroes=pd.Series(data=strength_levels, index=superheroes)
heroes
# Out:
# batman             100
# superman           120
# spiderman           90
# iron man            95
# captain america    110
# wonder woman       120
# dtype: int64

# %%
heroes.head(2)
# Out:
# batman      100
# superman    120
# dtype: int64

# %%
heroes.tail(4)
# Out:
# spiderman           90
# iron man            95
# captain america    110
# wonder woman       120
# dtype: int64

# %%
heroes.nunique()
# Out:
# 5

# %%
heroes.mean()
# Out:
# np.float64(105.83333333333333)

# %%
heroes.max()
# Out:
# 120

# %%
heroes.min()
# Out:
# 90

# %%
heroes*2
# Out:
# batman             200
# superman           240
# spiderman          180
# iron man           190
# captain america    220
# wonder woman       240
# dtype: int64

# %%
dict(heroes)
# Out:
# {'batman': np.int64(100),
#  'superman': np.int64(120),
#  'spiderman': np.int64(90),
#  'iron man': np.int64(95),
#  'captain america': np.int64(110),
#  'wonder woman': np.int64(120)}
